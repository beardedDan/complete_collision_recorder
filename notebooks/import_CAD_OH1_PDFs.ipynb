# %%
import os
import pandas as pd

df = pd.read_csv("../data/raw/index_files/combined_file.csv")
# Out:
# /tmp/ipykernel_2467495/1378915088.py:4: DtypeWarning: Columns (3,4,6,10,11,12,13,14,16,17,18,22,23,24,25,27,32,33,34,36,37,38,39,40,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/raw/index_files/combined_file.csv")

# %%
df.columns
# Out:
# Index(['OBJECTID', 'PRIMARYKEY', 'AGENCY', 'EVENT_NUMBER', 'REV_NUM',
#        'CALL_DATETIME', 'UPDATE_DATETIME', 'CALL_TYPE', 'CALL_DESC',
#        'EVENT_STATUS', 'PRIMARY_UNIT', 'PRIORITY', 'CALL_SOURCE', 'CVADDRESS',
#        'CVADDRESS_ZIP', 'APT', 'ZIP', 'X_COORD', 'Y_COORD', 'CURRENT_FLAG',
#        'CVCALLDATE', 'CVCALLDOW', 'CVCALLTIME', 'CVLEGEND', 'IWGEONAME',
#        'STATUS', 'SCORE', 'SIDE', 'X', 'Y', 'CV_WARDS', 'CV_DISTRICTS',
#        'ARRIVAL_DATETIME', 'SUB_CALL_TYPE', 'NATURE', 'PD_WARD', 'PD_ZONE',
#        'PD_DISTRICT', 'DISPO_DESC', 'CV_ZONES', 'CV_SPA', 'DISPO_DESC_FINAL',
#        'latitude', 'longitude'],
#       dtype='object')

# %%
event_ids = df["EVENT_NUMBER"].unique()

# %%
filtered_df = df[
    (df["CALL_DATETIME"] >= "2021-12-30 23:10:00")
    & (df["CALL_DATETIME"] <= "2021-12-30 23:20:00")
]

print(filtered_df)
# Out:
#          OBJECTID  PRIMARYKEY AGENCY  EVENT_NUMBER REV_NUM  \
# 5699558   5442126     7395844    CPD  202100392222       8
# 5699559   5442127     7395845    CPD  202100392223       9
# 5699560   5442128     7395848    CPD  202100392224       7
# 6108524   5447154     7395844    CPD  202100392222       8
# 6108525   5447155     7395845    CPD  202100392223       9
# 6108526   5447156     7395848    CPD  202100392224       7
# 6114711   5453391     7395844    CPD  202100392222       8
# 6114712   5453392     7395845    CPD  202100392223       9
# 6114713   5453393     7395848    CPD  202100392224       7
# 6120769   5466282     7395844    CPD  202100392222       8
# 6120770   5466283     7395845    CPD  202100392223       9
# 6120771   5466284     7395848    CPD  202100392224       7
# 6126682   5466282     7395844    CPD  202100392222       8
# 6126683   5466283     7395845    CPD  202100392223       9
# 6126684   5466284     7395848    CPD  202100392224       7
# 6414329   5459906     7395844    CPD  202100392222       8
# 6414330   5459907     7395845    CPD  202100392223       9
# 6414331   5459908     7395848    CPD  202100392224       7
#
#                CALL_DATETIME UPDATE_DATETIME CALL_TYPE  \
# 5699558  2021-12-30 23:10:12             NaN      DIST
# 5699559  2021-12-30 23:11:04             NaN      CWEL
# 5699560  2021-12-30 23:17:00             NaN      TRUN
# 6108524  2021-12-30 23:10:12             NaN      DIST
# 6108525  2021-12-30 23:11:04             NaN      CWEL
# 6108526  2021-12-30 23:17:00             NaN      TRUN
# 6114711  2021-12-30 23:10:12             NaN      DIST
# 6114712  2021-12-30 23:11:04             NaN      CWEL
# 6114713  2021-12-30 23:17:00             NaN      TRUN
# 6120769  2021-12-30 23:10:12             NaN      DIST
# 6120770  2021-12-30 23:11:04             NaN      CWEL
# 6120771  2021-12-30 23:17:00             NaN      TRUN
# 6126682  2021-12-30 23:10:12             NaN      DIST
# 6126683  2021-12-30 23:11:04             NaN      CWEL
# 6126684  2021-12-30 23:17:00             NaN      TRUN
# 6414329  2021-12-30 23:10:12             NaN      DIST
# 6414330  2021-12-30 23:11:04             NaN      CWEL
# 6414331  2021-12-30 23:17:00             NaN      TRUN
#
#                          CALL_DESC EVENT_STATUS  ... NATURE PD_WARD PD_ZONE  \
# 5699558       DISTURBANCE/NUISANCE            A  ...    NaN     7.0      51
# 5699559  CHECK WELFARE OF A PERSON            A  ...    NaN     6.0      44
# 5699560    TROUBLE - UNKNOWN CAUSE            A  ...    NaN     8.0      31
# 6108524       DISTURBANCE/NUISANCE            A  ...    NaN     7.0      51
# 6108525  CHECK WELFARE OF A PERSON            A  ...    NaN     6.0      44
# 6108526    TROUBLE - UNKNOWN CAUSE            A  ...    NaN     8.0      31
# 6114711       DISTURBANCE/NUISANCE            A  ...    NaN     7.0      51
# 6114712  CHECK WELFARE OF A PERSON            A  ...    NaN     6.0      44
# 6114713    TROUBLE - UNKNOWN CAUSE            A  ...    NaN     8.0      31
# 6120769       DISTURBANCE/NUISANCE            A  ...    NaN     7.0      51
# 6120770  CHECK WELFARE OF A PERSON            A  ...    NaN     6.0      44
# 6120771    TROUBLE - UNKNOWN CAUSE            A  ...    NaN     8.0      31
# 6126682       DISTURBANCE/NUISANCE            A  ...    NaN     7.0    51.0
# 6126683  CHECK WELFARE OF A PERSON            A  ...    NaN     6.0    44.0
# 6126684    TROUBLE - UNKNOWN CAUSE            A  ...    NaN     8.0    31.0
# 6414329       DISTURBANCE/NUISANCE            A  ...    NaN     7.0      51
# 6414330  CHECK WELFARE OF A PERSON            A  ...    NaN     6.0      44
# 6414331    TROUBLE - UNKNOWN CAUSE            A  ...    NaN     8.0      31
#
#         PD_DISTRICT       DISPO_DESC CV_ZONES            CV_SPA  \
# 5699558          D5         INFO, NW      5-1             Hough
# 5699559          D4    INFO, ADV, NR      4-4  Buckeye-Woodhill
# 5699560          D3   TOUR, GOA, UTL      3-1          Downtown
# 6108524          D5         INFO, NW      5-1             Hough
# 6108525          D4    INFO, ADV, NR      4-4  Buckeye-Woodhill
# 6108526          D3   TOUR, GOA, UTL      3-1          Downtown
# 6114711          D5         INFO, NW      5-1             Hough
# 6114712          D4    INFO, ADV, NR      4-4  Buckeye-Woodhill
# 6114713          D3   TOUR, GOA, UTL      3-1          Downtown
# 6120769          D5         INFO, NW      5-1             Hough
# 6120770          D4    INFO, ADV, NR      4-4  Buckeye-Woodhill
# 6120771          D3   TOUR, GOA, UTL      3-1          Downtown
# 6126682          D5         INFO, NW      5-1             Hough
# 6126683          D4    INFO, ADV, NR      4-4  Buckeye-Woodhill
# 6126684          D3   TOUR, GOA, UTL      3-1          Downtown
# 6414329          D5         INFO, NW      5-1             Hough
# 6414330          D4    INFO, ADV, NR      4-4  Buckeye-Woodhill
# 6414331          D3   TOUR, GOA, UTL      3-1          Downtown
#
#         DISPO_DESC_FINAL   latitude  longitude
# 5699558               NW -81.651871  41.517792
# 5699559               NR -81.603854  41.481231
# 5699560              UTL -81.675531  41.506102
# 6108524               NW -81.651871  41.517792
# 6108525               NR -81.603854  41.481231
# 6108526              UTL -81.675531  41.506102
# 6114711               NW -81.651871  41.517792
# 6114712               NR -81.603854  41.481231
# 6114713              UTL -81.675531  41.506102
# 6120769               NW -81.651871  41.517792
# 6120770               NR -81.603854  41.481231
# 6120771              UTL -81.675531  41.506102
# 6126682               NW -81.651871  41.517792
# 6126683               NR -81.603854  41.481231
# 6126684              UTL -81.675531  41.506102
# 6414329               NW -81.651871  41.517792
# 6414330               NR -81.603854  41.481231
# 6414331              UTL -81.675531  41.506102
#
# [18 rows x 44 columns]

# %%
df.head()
# Out:
#    OBJECTID  PRIMARYKEY AGENCY  EVENT_NUMBER REV_NUM        CALL_DATETIME  \
# 0   9609612     6290713    CPD  201900377675       9  2019-12-10 12:48:14
# 1   9609613     6290716    CPD  201900377676       8  2019-12-10 12:52:35
# 2   9609614     6290717    CPD  201900377677       9  2019-12-10 12:53:23
# 3   9609615     6290718    CPD  201900377678       8  2019-12-10 12:53:28
# 4   9609616     6290720    CPD  201900377679       9  2019-12-10 12:53:36
#
#   UPDATE_DATETIME CALL_TYPE                        CALL_DESC EVENT_STATUS  \
# 0             NaN      MNTL  MENTAL - NON VIOLENT DISTURBING            A
# 1             NaN        PC                   PROPERTY CRIME            A
# 2             NaN      THTX  THREATS - SUSP ON SCENE/IN AREA            A
# 3             NaN      S911                  SILENT 911 CALL            A
# 4             NaN       TFC                  TRAFFIC PROBLEM            A
#
#    ... NATURE PD_WARD PD_ZONE PD_DISTRICT      DISPO_DESC CV_ZONES  \
# 0  ...    NaN     4.0    44.0          D4      INFO, ASST    414.0
# 1  ...    NaN    18.0    13.0          D1      INFO, REPT    113.0
# 2  ...    NaN    17.0    13.0          D1   INFO, ADV, RH    113.0
# 3  ...    NaN    19.0    12.0          D1       INFO, ADV    112.0
# 4  ...    NaN    15.0    21.0          D2              OK    211.0
#
#            CV_SPA DISPO_DESC_FINAL   latitude  longitude
# 0  Mount Pleasant             ASST -81.621004  41.471984
# 1       Jefferson             REPT -81.790767  41.444297
# 2       Jefferson               RH -81.777242  41.452420
# 3          Kamm's              ADV -81.805348  41.458932
# 4       Ohio City               OK -81.718906  41.478400
#
# [5 rows x 44 columns]

# %%
traffic_ids = df[df["CALL_DESC"] == "NON FATAL ACCIDENT - PEDESTRIAN STRUCK"][
    "EVENT_NUMBER"
]
filtered_traffic_ids = traffic_ids[
    traffic_ids.astype(str).str.startswith(("2020", "2021", "2022", "2023"))
]
filtered_traffic_ids = filtered_traffic_ids.unique()

# %%
len(traffic_ids)
# Out:
# 14642

# %%
test_ids = np.array([202400253534])

# %%
# import os
# import requests
# import numpy as np

# # Assume EVENT_ID is your numpy array of event IDs
# EVENT_ID = test_ids

# # Base URL for concatenation
# base_url = "https://czt313d2a2.execute-api.us-east-1.amazonaws.com/dev/cad/"

# # Folder where the PDF files will be saved
# output_folder = "../data/raw/cad_pdf_files/"
# os.makedirs(output_folder, exist_ok=True)  # Create the folder if it doesn't exist

# # Paths to central files for found and not found PDFs
# found_pdfs_file = "../data/raw/cad_pdf_files/found_pdfs.txt"
# not_found_pdfs_file = "../data/raw/cad_pdf_files/not_found_pdfs.txt"

# # Ensure the central files exist
# open(found_pdfs_file, 'a').close()  # Create if doesn't exist
# open(not_found_pdfs_file, 'a').close()  # Create if doesn't exist

# # Load already processed IDs from not_found_pdfs.txt
# with open(not_found_pdfs_file, 'r') as f:
#     not_found_ids = set(line.strip() for line in f)

# # Function to check if the PDF exists and download it
# def download_pdf(event_id):
#     pdf_url = f"{base_url}{event_id}.pdf"
#     print(pdf_url)
#     try:
#         # Allow the redirect and follow to the pre-signed URL
#         response = requests.head(pdf_url, allow_redirects=True, timeout=10)
#         print(response.headers)

#         # Check if we get a valid response (status_code == 200) after the redirect
#         if response.status_code == 200:
#             # Follow the redirected URL (pre-signed URL) to download the PDF
#             response = requests.get(pdf_url, allow_redirects=True)
#             local_filename = os.path.join(output_folder, f"{event_id}.pdf")
#             with open(local_filename, 'wb') as f:
#                 for chunk in response.iter_content(chunk_size=8192):
#                     if chunk:
#                         f.write(chunk)
#             # Add event_id to found_pdfs.txt
#             with open(found_pdfs_file, 'a') as f_found:
#                 f_found.write(f"{event_id}\n")
#             print(f"Downloaded: {local_filename}")
#         else:
#             # Add event_id to not_found_pdfs.txt if file not found
#             with open(not_found_pdfs_file, 'a') as f_not_found:
#                 f_not_found.write(f"{event_id}\n")
#             print(f"File not found for EVENT_ID {event_id}.")
#     except requests.exceptions.RequestException as e:
#         # Add event_id to not_found_pdfs.txt in case of an error
#         with open(not_found_pdfs_file, 'a') as f_not_found:
#             f_not_found.write(f"{event_id}\n")
#         print(f"Error downloading {event_id}: {e}")

# # Total number of IDs
# total_ids = len(EVENT_ID)
# percent_step = total_ids // 100  # 1% progress
# next_percent = percent_step

# # Iterate over each EVENT_ID in the numpy array and attempt to download the PDF
# for idx, event_id in enumerate(EVENT_ID, 1):
#     # Skip if the event_id is already in not_found_pdfs.txt
#     if str(event_id) in not_found_ids:
#         continue

#     download_pdf(event_id)

#     # Print progress every 1%
#     if idx >= next_percent:
#         print(f"{(idx / total_ids) * 100:.2f}% processed ({idx} of {total_ids})")
#         next_percent += percent_step

# print("Process completed.")
# Out:
# https://czt313d2a2.execute-api.us-east-1.amazonaws.com/dev/cad/202400253534.pdf
# {'x-amz-request-id': 'TAP858944YN46A2G', 'x-amz-id-2': '4+sq3JvIR2R+jcKt03BAN/7YZReLWyN6tcNtgff7EXCSwbb2VFGsPILiKIpa9BVWVkcXt4K+yI4=', 'Content-Type': 'application/xml', 'Date': 'Thu, 19 Sep 2024 01:55:58 GMT', 'Server': 'AmazonS3'}
# File not found for EVENT_ID 202400253534.
# 100.00% processed (1 of 1)
# Process completed.

# %%
import os
import time
import numpy as np
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

# Set up Selenium WebDriver
download_dir = os.path.abspath(
    "../data/raw/cad_pdf_files"
)  # Absolute path to the download folder
chrome_options = Options()
chrome_options.add_experimental_option(
    "prefs",
    {
        "download.default_directory": download_dir,  # Set download directory
        "download.prompt_for_download": False,  # Disable prompt for download
        "download.directory_upgrade": True,
        "plugins.always_open_pdf_externally": True,  # Auto-download PDFs instead of opening in Chrome
    },
)

# Initialize the WebDriver (Make sure you have the ChromeDriver or GeckoDriver in your PATH)
driver = webdriver.Chrome(options=chrome_options)

# Assume EVENT_ID is your numpy array of event IDs
EVENT_ID = filtered_traffic_ids

# Base URL for concatenation
base_url = "https://czt313d2a2.execute-api.us-east-1.amazonaws.com/dev/cad/"

# Folder where the PDF files will be saved
output_folder = "../data/raw/cad_pdf_files/"
os.makedirs(
    output_folder, exist_ok=True
)  # Create the folder if it doesn't exist

# Paths to central files for found and not found PDFs
found_pdfs_file = "../data/raw/cad_pdf_files/found_pdfs.txt"
not_found_pdfs_file = "../data/raw/cad_pdf_files/not_found_pdfs.txt"

# Ensure the central files exist
open(found_pdfs_file, "a").close()  # Create if doesn't exist
open(not_found_pdfs_file, "a").close()  # Create if doesn't exist

# Load already processed IDs from not_found_pdfs.txt
with open(not_found_pdfs_file, "r") as f:
    not_found_ids = set(line.strip() for line in f)

with open(found_pdfs_file, "r") as f:
    found_ids = set(line.strip() for line in f)


# Function to download the PDF using Selenium
def download_pdf(event_id):
    pdf_url = f"{base_url}{event_id}.pdf"
    # print(f"Attempting to download: {pdf_url}")
    try:
        # Open the URL in Selenium
        driver.get(pdf_url)

        # Wait for a few seconds to allow the PDF to download
        time.sleep(5)  # Adjust this if needed

        # Check if the file exists in the download directory
        local_filename = os.path.join(output_folder, f"{event_id}.pdf")
        if os.path.isfile(local_filename):
            # Add event_id to found_pdfs.txt
            with open(found_pdfs_file, "a") as f_found:
                f_found.write(f"{event_id}\n")
            # print(f"Downloaded: {local_filename}")
        else:
            # Add event_id to not_found_pdfs.txt if file not found
            with open(not_found_pdfs_file, "a") as f_not_found:
                f_not_found.write(f"{event_id}\n")
            # print(f"File not found for EVENT_ID {event_id}.")
    except Exception as e:
        # Add event_id to not_found_pdfs.txt in case of an error
        with open(not_found_pdfs_file, "a") as f_not_found:
            f_not_found.write(f"{event_id}\n")
        # print(f"Error downloading {event_id}: {e}")


# Total number of IDs
total_ids = len(EVENT_ID)
percent_step = total_ids // 100  # 1% progress
next_percent = percent_step

# Iterate over each EVENT_ID in the numpy array and attempt to download the PDF
for idx, event_id in enumerate(EVENT_ID, 1):
    # Skip if the event_id is already in not_found_pdfs.txt
    if str(event_id) in not_found_ids:
        continue
    if str(event_id) in found_ids:
        continue

    download_pdf(event_id)

    # Print progress every 1%
    if idx >= next_percent:
        print(
            f"{(idx / total_ids) * 100:.2f}% processed ({idx} of {total_ids})"
        )
        next_percent += percent_step

# Close the browser after the process is completed
driver.quit()

print("Process completed.")
# Out:
# 0.98% processed (22 of 2236)
# 1.97% processed (44 of 2236)
# 2.95% processed (66 of 2236)
# 3.94% processed (88 of 2236)
# 4.92% processed (110 of 2236)
# 5.90% processed (132 of 2236)
# 6.89% processed (154 of 2236)
# 7.87% processed (176 of 2236)
# 8.86% processed (198 of 2236)
# 9.84% processed (220 of 2236)
# 10.82% processed (242 of 2236)
# 11.81% processed (264 of 2236)
# 12.79% processed (286 of 2236)
# 13.77% processed (308 of 2236)
# 14.76% processed (330 of 2236)
# 15.74% processed (352 of 2236)
# 16.73% processed (374 of 2236)
# 17.71% processed (396 of 2236)
# 18.69% processed (418 of 2236)
# 19.68% processed (440 of 2236)
# 20.66% processed (462 of 2236)
# 21.65% processed (484 of 2236)
# 22.63% processed (506 of 2236)
# 23.61% processed (528 of 2236)
# 24.60% processed (550 of 2236)
# 25.58% processed (572 of 2236)
# 26.57% processed (594 of 2236)
# 27.55% processed (616 of 2236)
# 28.53% processed (638 of 2236)
# 29.52% processed (660 of 2236)
# 30.50% processed (682 of 2236)
# 31.48% processed (704 of 2236)
# 32.47% processed (726 of 2236)
# 33.45% processed (748 of 2236)
# 34.44% processed (770 of 2236)
# 35.42% processed (792 of 2236)
# 36.40% processed (814 of 2236)
# 37.39% processed (836 of 2236)
# 38.37% processed (858 of 2236)
# 39.36% processed (880 of 2236)
# 40.34% processed (902 of 2236)
# 41.32% processed (924 of 2236)
# 42.31% processed (946 of 2236)
# 43.29% processed (968 of 2236)
# 44.28% processed (990 of 2236)
# 45.26% processed (1012 of 2236)
# 46.24% processed (1034 of 2236)
# 47.23% processed (1056 of 2236)
# 48.21% processed (1078 of 2236)
# 49.19% processed (1100 of 2236)
# 50.18% processed (1122 of 2236)
# 51.16% processed (1144 of 2236)
# 52.15% processed (1166 of 2236)
# 53.13% processed (1188 of 2236)
# 54.11% processed (1210 of 2236)
# 55.10% processed (1232 of 2236)
# 56.08% processed (1254 of 2236)
# 57.07% processed (1276 of 2236)
# 58.05% processed (1298 of 2236)
# 59.03% processed (1320 of 2236)
# 60.02% processed (1342 of 2236)
# 61.00% processed (1364 of 2236)
# 61.99% processed (1386 of 2236)
# 62.97% processed (1408 of 2236)
# 63.95% processed (1430 of 2236)
# 64.94% processed (1452 of 2236)
# 65.92% processed (1474 of 2236)
# 66.91% processed (1496 of 2236)
# 67.89% processed (1518 of 2236)
# 68.87% processed (1540 of 2236)
# 69.86% processed (1562 of 2236)
# 70.84% processed (1584 of 2236)
# 71.82% processed (1606 of 2236)
# 72.81% processed (1628 of 2236)
# 73.79% processed (1650 of 2236)
# 74.78% processed (1672 of 2236)
# 75.76% processed (1694 of 2236)
# 76.74% processed (1716 of 2236)
# 77.73% processed (1738 of 2236)
# 78.71% processed (1760 of 2236)
# 79.70% processed (1782 of 2236)
# 80.68% processed (1804 of 2236)
# 81.66% processed (1826 of 2236)
# 82.65% processed (1848 of 2236)
# 83.63% processed (1870 of 2236)
# 84.62% processed (1892 of 2236)
# 85.60% processed (1914 of 2236)
# 86.58% processed (1936 of 2236)
# 87.57% processed (1958 of 2236)
# 88.55% processed (1980 of 2236)
# 89.53% processed (2002 of 2236)
# 90.52% processed (2024 of 2236)
# 91.50% processed (2046 of 2236)
# 92.49% processed (2068 of 2236)
# 93.47% processed (2090 of 2236)
# 94.45% processed (2112 of 2236)
# 95.44% processed (2134 of 2236)
# 96.42% processed (2156 of 2236)
# 97.41% processed (2178 of 2236)
# 98.39% processed (2200 of 2236)
# 99.37% processed (2222 of 2236)
# Process completed.

# %%
import os
import time
import numpy as np
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

# Set up Selenium WebDriver
download_dir = os.path.abspath(
    "../data/raw/oh1_pdf_files"
)  # Absolute path to the download folder
chrome_options = Options()
chrome_options.add_experimental_option(
    "prefs",
    {
        "download.default_directory": download_dir,  # Set download directory
        "download.prompt_for_download": False,  # Disable prompt for download
        "download.directory_upgrade": True,
        "plugins.always_open_pdf_externally": True,  # Auto-download PDFs instead of opening in Chrome
    },
)

# Initialize the WebDriver (Make sure you have the ChromeDriver or GeckoDriver in your PATH)
driver = webdriver.Chrome(options=chrome_options)

# Assume EVENT_ID is your numpy array of event IDs
EVENT_ID = filtered_traffic_ids

# Base URL for concatenation
base_url = "https://czt313d2a2.execute-api.us-east-1.amazonaws.com/dev/oh1_crash_report/"

# Folder where the PDF files will be saved
output_folder = "../data/raw/oh1_pdf_files/"
os.makedirs(
    output_folder, exist_ok=True
)  # Create the folder if it doesn't exist

# Paths to central files for found and not found PDFs
found_oh1_pdfs_file = "../data/raw/oh1_pdf_files/found_pdfs.txt"
not_found_oh1_pdfs_file = "../data/raw/oh1_pdf_files/not_found_pdfs.txt"

# Ensure the central files exist
open(found_oh1_pdfs_file, "a").close()  # Create if doesn't exist
open(not_found_oh1_pdfs_file, "a").close()  # Create if doesn't exist

with open(found_oh1_pdfs_file, "r") as f:
    found_oh1_ids = set(line.strip() for line in f)

# Load already processed IDs from not_found_pdfs.txt
with open(not_found_oh1_pdfs_file, "r") as f:
    not_found_oh1_ids = set(line.strip() for line in f)


# Function to download the PDF using Selenium
def download_pdf(event_id):
    pdf_url = f"{base_url}{event_id}.pdf"
    # print(f"Attempting to download: {pdf_url}")
    try:
        # Open the URL in Selenium
        driver.get(pdf_url)

        # Wait for a few seconds to allow the PDF to download
        time.sleep(5)  # Adjust this if needed

        # Check if the file exists in the download directory
        local_filename = os.path.join(output_folder, f"{event_id}.pdf")
        if os.path.isfile(local_filename):
            # Add event_id to found_pdfs.txt
            with open(found_oh1_pdfs_file, "a") as f_found:
                f_found.write(f"{event_id}\n")
            # print(f"Downloaded: {local_filename}")
        else:
            # Add event_id to not_found_pdfs.txt if file not found
            with open(not_found_oh1_pdfs_file, "a") as f_not_found:
                f_not_found.write(f"{event_id}\n")
            # print(f"File not found for EVENT_ID {event_id}.")
    except Exception as e:
        # Add event_id to not_found_pdfs.txt in case of an error
        with open(not_found_oh1_pdfs_file, "a") as f_not_found:
            f_not_found.write(f"{event_id}\n")
        # print(f"Error downloading {event_id}: {e}")


# Total number of IDs
total_ids = len(EVENT_ID)
percent_step = total_ids // 100  # 1% progress
next_percent = percent_step

# Iterate over each EVENT_ID in the numpy array and attempt to download the PDF
for idx, event_id in enumerate(EVENT_ID, 1):
    # Skip if the event_id is already in not_found_pdfs.txt
    if str(event_id) in not_found_oh1_ids:
        continue
    if str(event_id) in found_oh1_ids:
        continue

    download_pdf(event_id)

    # Print progress every 1%
    if idx >= next_percent:
        print(
            f"{(idx / total_ids) * 100:.2f}% processed ({idx} of {total_ids})"
        )
        next_percent += percent_step

# Close the browser after the process is completed
driver.quit()

print("Process completed.")
# Out:
# 0.98% processed (22 of 2236)
# 1.97% processed (44 of 2236)
# 2.95% processed (66 of 2236)
# 3.94% processed (88 of 2236)
# 4.92% processed (110 of 2236)
# 5.90% processed (132 of 2236)
# 6.89% processed (154 of 2236)
# 7.87% processed (176 of 2236)
# 8.86% processed (198 of 2236)
# 9.84% processed (220 of 2236)
# 10.82% processed (242 of 2236)
# 11.81% processed (264 of 2236)
# 12.79% processed (286 of 2236)
# 13.77% processed (308 of 2236)
# 14.76% processed (330 of 2236)
# 15.74% processed (352 of 2236)
# 16.73% processed (374 of 2236)
# 17.71% processed (396 of 2236)
# 18.69% processed (418 of 2236)
# 19.68% processed (440 of 2236)
# 20.66% processed (462 of 2236)
# 21.65% processed (484 of 2236)
# 22.63% processed (506 of 2236)
# 23.61% processed (528 of 2236)
# 24.60% processed (550 of 2236)
# 25.58% processed (572 of 2236)
# 26.57% processed (594 of 2236)
# 27.55% processed (616 of 2236)
# 28.53% processed (638 of 2236)
# 29.52% processed (660 of 2236)
# 30.50% processed (682 of 2236)
# 31.48% processed (704 of 2236)
# 32.47% processed (726 of 2236)
# 33.45% processed (748 of 2236)
# 34.44% processed (770 of 2236)
# 35.42% processed (792 of 2236)
# 36.40% processed (814 of 2236)
# 37.39% processed (836 of 2236)
# 38.37% processed (858 of 2236)
# 39.36% processed (880 of 2236)
# 40.34% processed (902 of 2236)
# 41.32% processed (924 of 2236)
# 42.31% processed (946 of 2236)
# 43.29% processed (968 of 2236)
# 44.28% processed (990 of 2236)
# 45.26% processed (1012 of 2236)
# 46.24% processed (1034 of 2236)
# 47.23% processed (1056 of 2236)
# 48.21% processed (1078 of 2236)
# 49.19% processed (1100 of 2236)
# 50.18% processed (1122 of 2236)
# 51.16% processed (1144 of 2236)
# 52.15% processed (1166 of 2236)
# 53.13% processed (1188 of 2236)
# 54.11% processed (1210 of 2236)
# 55.10% processed (1232 of 2236)
# 56.08% processed (1254 of 2236)
# 57.07% processed (1276 of 2236)
# 58.05% processed (1298 of 2236)
# 59.03% processed (1320 of 2236)
# 60.02% processed (1342 of 2236)
# 61.00% processed (1364 of 2236)
# 61.99% processed (1386 of 2236)
# 62.97% processed (1408 of 2236)
# 63.95% processed (1430 of 2236)
# 64.94% processed (1452 of 2236)
# 65.92% processed (1474 of 2236)
# 66.91% processed (1496 of 2236)
# 67.89% processed (1518 of 2236)
# 68.87% processed (1540 of 2236)
# 69.86% processed (1562 of 2236)
# 70.84% processed (1584 of 2236)
# 71.82% processed (1606 of 2236)
# 72.81% processed (1628 of 2236)
# 73.79% processed (1650 of 2236)
# 74.78% processed (1672 of 2236)
# 75.76% processed (1694 of 2236)
# 76.74% processed (1716 of 2236)
# 77.73% processed (1738 of 2236)
# 78.71% processed (1760 of 2236)
# 79.70% processed (1782 of 2236)
# 80.68% processed (1804 of 2236)
# 81.66% processed (1826 of 2236)
# 82.65% processed (1848 of 2236)
# 83.63% processed (1870 of 2236)
# 84.62% processed (1892 of 2236)
# 85.60% processed (1914 of 2236)
# 86.58% processed (1936 of 2236)
# 87.57% processed (1958 of 2236)
# 88.55% processed (1980 of 2236)
# 89.53% processed (2002 of 2236)
# 90.52% processed (2024 of 2236)
# 91.50% processed (2046 of 2236)
# 92.49% processed (2068 of 2236)
# 93.47% processed (2090 of 2236)
# 94.45% processed (2112 of 2236)
# 95.44% processed (2134 of 2236)
# 96.42% processed (2156 of 2236)
# 97.41% processed (2178 of 2236)
# 98.39% processed (2200 of 2236)
# 99.37% processed (2222 of 2236)
# Process completed.

# %%
# Theres an import error for a lot of files that did not import but a shell of the file
# did import so this will recategorize those files as not imported

folder_path = "../data/raw/oh1_pdf_files"
not_found_pdfs_file = "../data/raw/oh1_pdf_files/not_found_pdfs.txt"

size_threshold = 13 * 1024

with open(not_found_pdfs_file, "a") as not_found_file:
    for filename in os.listdir(folder_path):
        if filename.endswith(".pdf"):
            file_path = os.path.join(folder_path, filename)
            file_size = os.path.getsize(file_path)
            if file_size < size_threshold:
                event_id = os.path.splitext(filename)[0]
                not_found_file.write(f"{event_id}\n")
